# %% [markdown]
# <a href="https://colab.research.google.com/github/ashreenn/complete_rag_systems/blob/main/Data_Ingestion_And_Data_Parsing_Techniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# uv is a modern Python package + environment manager.
#
# Earlier Python developers used:
#
#
#
#
#
# * pip → install packages
# * venv → create virtual environments
#
#
#
# * requirements.txt → dependency list
#
#
#
#
#
#
#
#
#
# Now uv combines all of these into one fast tool.

# %%
# Install uv (modern Python package & environment manager)
# Downloads and installs uv on the Colab Linux machine
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# Out:
# downloading uv 0.11.12 x86_64-unknown-linux-gnu
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %%
# Add uv location to PATH
# Makes the terminal recognize the "uv" command
import os
os.environ["PATH"] += ":/root/.local/bin"

# %%
# Check whether uv installed correctly
# Shows installed uv version
# !uv --version
# Out:
# uv 0.11.12 (x86_64-unknown-linux-gnu)

# %%
# Create a new Python project
# Generates project folder with pyproject.toml
# !uv init my_project
# Out:
# Initialized project `my-project` at `/content/my_project`

# %%
# Move inside the project folder
# All next commands/files will work inside this project
# %cd my_project
# Out:
# /content/my_project

# %%
# Show files inside the project
# Lists all project files/folders
# !ls
# Out:
# main.py  pyproject.toml  README.md

# %%
# Install Python packages/dependencies
# Example: numpy and pandas
# %cd /content
# Out:
# /content

# %%
# !rm -rf /content/my_project/my_project

# %%
# %cd /content/my_project
# Out:
# /content/my_project

# %%
#Helping developers build AI applications using LLMs easily.
#It acts like a toolkit/framework for connecting:
# LLMs
# databases
# PDFs
# APIs
# chatbots
# memory
# tools
# into one AI workflow.
# !uv add langchain
# Out:
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 34 packages in 532ms
# Prepared 33 packages in 1.06s
# Installed 33 packages in 156ms
#  + annotated-types==0.7.0
#  + anyio==4.13.0
#  + certifi==2026.4.22
#  + charset-normalizer==3.4.7
#  + h11==0.16.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + idna==3.14
#  + jsonpatch==1.33
#  + jsonpointer==3.1.1
#  + langchain==1.2.18
#  + langchain-core==1.3.3
#  + langchain-protocol==0.0.15
#  + langgraph==1.1.10
#  + langgraph-checkpoint==4.0.3
#  + langgraph-prebuilt==1.0.13
#  + langgraph-sdk==0.3.14
#  + langsmith==0.8.3
#  + orjson==3.11.9
#  + ormsgpack==1.12.2
#  + packaging==26.2
#  + pydantic==2.13.4
#  + pydantic-core==2.46.4
#  + pyyaml==6.0.3
#  + requests==2.33.1
#  + requests-toolbelt==1.0.0
#  + tenacity==9.1.4
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + urllib3==2.7.0
#  + uuid-utils==0.14.1
#  + xxhash==3.7.0
#  + zstandard==0.25.0

# %%
# !uv add langchain-groq
#It connects:
# LangChain
# with
# Groq
#  AI models.
# So this package allows LangChain to use Groq’s LLM APIs easily.
# Out:
# Resolved 38 packages in 331ms
# Prepared 4 packages in 85ms
# Installed 4 packages in 11ms
#  + distro==1.9.0
#  + groq==0.37.1
#  + langchain-groq==1.1.2
#  + sniffio==1.3.1

# %%
# !uv add faiss-cpu
#FAISS is used for:
#Fast similarity search on vectors (embeddings).
# Out:
# Resolved 40 packages in 448ms
# Prepared 2 packages in 3.10s
# Installed 2 packages in 87ms
#  + faiss-cpu==1.13.2
#  + numpy==2.4.4

# %%
# !uv add tiktoken
#It is used for:
# Converting text into tokens.
# LLMs do not understand words directly.
# Out:
# Resolved 42 packages in 841ms
# Prepared 2 packages in 145ms
# Installed 2 packages in 5ms
#  + regex==2026.5.9
#  + tiktoken==0.12.0

# %%
# !uv add langchain-community
# It provides:
# Community-built integrations and tools for LangChain.
# Instead of keeping everything inside main LangChain, many integrations are separated into this package.
# Out:
# Resolved 62 packages in 856ms
# Prepared 20 packages in 504ms
# Installed 20 packages in 65ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.5
#  + aiosignal==1.4.0
#  + attrs==26.1.0
#  + dataclasses-json==0.6.7
#  + frozenlist==1.8.0
#  + greenlet==3.5.0
#  + httpx-sse==0.4.3
#  + langchain-classic==1.0.7
#  + langchain-community==0.4.1
#  + langchain-text-splitters==1.1.2
#  + marshmallow==3.26.2
#  + multidict==6.7.1
#  + mypy-extensions==1.1.0
#  + propcache==0.5.2
#  + pydantic-settings==2.14.1
#  + python-dotenv==1.2.2
#  + sqlalchemy==2.0.49
#  + typing-inspect==0.9.0
#  + yarl==1.23.0

# %%
# !uv add langchain-openai
# It connects:

# LangChain
# with
# OpenAI API

# So you can use:

# GPT models
# embeddings
# chat models

# inside LangChain easily.
# Out:
# Resolved 67 packages in 214ms
# Prepared 4 packages in 206ms
# Installed 4 packages in 27ms
#  + jiter==0.14.0
#  + langchain-openai==1.2.1
#  + openai==2.36.0
#  + tqdm==4.67.3

# %%
# !uv add chromadb
# ChromaDB is a:

# Vector database used to store and search embeddings.

# It is heavily used in:

# RAG systems
# AI search
# chatbot memory
# semantic search
# Out:
# Resolved 118 packages in 531ms
# Prepared 51 packages in 2.11s
# Installed 51 packages in 90ms
#  + annotated-doc==0.0.4
#  + bcrypt==5.0.0
#  + build==1.5.0
#  + chromadb==1.5.9
#  + click==8.3.3
#  + durationpy==0.10
#  + filelock==3.29.0
#  + flatbuffers==25.12.19
#  + fsspec==2026.4.0
#  + googleapis-common-protos==1.75.0
#  + grpcio==1.80.0
#  + hf-xet==1.5.0
#  + httptools==0.7.1
#  + huggingface-hub==1.14.0
#  + importlib-metadata==8.7.1
#  + importlib-resources==7.1.0
#  + jsonschema==4.26.0
#  + jsonschema-specifications==2025.9.1
#  + kubernetes==35.0.0
#  + markdown-it-py==4.2.0
#  + mdurl==0.1.2
#  + mmh3==5.2.1
#  + oauthlib==3.3.1
#  + onnxruntime==1.26.0
#  + opentelemetry-api==1.41.1
#  + opentelemetry-exporter-otlp-proto-common==1.41.1
#  + opentelemetry-exporter-otlp-proto-grpc==1.41.1
#  + opentelemetry-proto==1.41.1
#  + opentelemetry-sdk==1.41.1
#  + opentelemetry-semantic-conventions==0.62b1
#  + overrides==7.7.0
#  + protobuf==6.33.6
#  + pybase64==1.4.3
# ...

# %%
# !uv add sentence-transformers
# It converts text into:

# embeddings (vectors)

# so AI systems can understand semantic meaning.
# Out:
# Resolved 151 packages in 390ms
# Prepared 34 packages in 1m 00s
# Uninstalled 1 package in 27ms
# Installed 34 packages in 486ms
#  + cuda-bindings==13.2.0
#  + cuda-pathfinder==1.5.4
#  + cuda-toolkit==13.0.2
#  + jinja2==3.1.6
#  + joblib==1.5.3
#  + markupsafe==3.0.3
#  + mpmath==1.3.0
#  + networkx==3.6.1
#  + nvidia-cublas==13.1.0.3
#  + nvidia-cuda-cupti==13.0.85
#  + nvidia-cuda-nvrtc==13.0.88
#  + nvidia-cuda-runtime==13.0.96
#  + nvidia-cudnn-cu13==9.19.0.56
#  + nvidia-cufft==12.0.0.61
#  + nvidia-cufile==1.15.1.6
#  + nvidia-curand==10.4.0.35
#  + nvidia-cusolver==12.0.4.66
#  + nvidia-cusparse==12.6.3.3
#  + nvidia-cusparselt-cu13==0.8.0
#  + nvidia-nccl-cu13==2.28.9
#  + nvidia-nvjitlink==13.0.88
#  + nvidia-nvshmem-cu13==3.4.5
#  + nvidia-nvtx==13.0.85
#  + safetensors==0.7.0
#  + scikit-learn==1.8.0
#  + scipy==1.17.1
#  + sentence-transformers==5.4.1
#  + setuptools==81.0.0
#  + sympy==1.14.0
#  + threadpoolctl==3.6.0
#  - tokenizers==0.23.1
#  + tokenizers==0.22.2
# ...

# %%
# !uv add pypdf
# It is used for:

# Reading and extracting text/data from PDF files.
# Out:
# Resolved 152 packages in 482ms
# Prepared 1 package in 45ms
# Installed 1 package in 3ms
#  + pypdf==6.11.0

# %%
# !uv add python-dotenv
#Load secret/configuration values from a .env file into your Python application.
# Out:
# Resolved 152 packages in 222ms
# Checked 150 packages in 3ms

# %%
# !uv add ipykernel
# It acts like:

# A bridge between Jupyter notebooks and your Python environment.

#if you are already using Google Colab, then usually you do not need:
# Out:
# Resolved 180 packages in 582ms
# Prepared 25 packages in 1.46s
# Installed 25 packages in 261ms
#  + asttokens==3.0.1
#  + comm==0.2.3
#  + debugpy==1.8.20
#  + decorator==5.2.1
#  + executing==2.2.1
#  + ipykernel==7.2.0
#  + ipython==9.13.0
#  + ipython-pygments-lexers==1.1.1
#  + jedi==0.20.0
#  + jupyter-client==8.8.0
#  + jupyter-core==5.9.1
#  + matplotlib-inline==0.2.2
#  + nest-asyncio==1.6.0
#  + parso==0.8.7
#  + pexpect==4.9.0
#  + platformdirs==4.9.6
#  + prompt-toolkit==3.0.52
#  + psutil==7.2.2
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyzmq==27.1.0
#  + stack-data==0.6.3
#  + tornado==6.5.5
#  + traitlets==5.15.0
#  + wcwidth==0.7.0

# %% [markdown]
# **DATA INGESTION AND DATA PARSING**

# %%
#Data ingestion means:
#Collecting/importing data from different sources into a system for storage or processing.

#Data parsing means:
#Converting raw/unstructured data into a readable and structured format.

# %%
# Built-in Python module for interacting with the operating system
# Used for file paths, folders, environment variables, etc.
import os
# Imports type hints from Python typing module
# Helps write cleaner and more understandable code
# Any → variable can store any datatype
from typing import List,Dict,Any
# Imports pandas library for data analysis and handling tables/dataframes
import pandas as pd

# %%
# Imports the Document class from LangChain
# Used to store and manage text data with metadata
#Metadata means:
#“Data about data”
#It gives extra information that describes actual data.
from langchain_core.documents import Document

# %%
# !pip install -q langchain-text-splitters
#Package containing text chunking utilities.
#Used in:
# RAG
# document AI
# PDF chatbots
from langchain_text_splitters import (
    RecursiveCharacterTextSplitter,
#     intelligently splits text while preserving context.
# It tries:
# paragraphs
# sentences
# spaces
# characters
# until chunk fits.
    CharacterTextSplitter,
#It splits purely based on:
# character count
# Example:
# 1000 characters per chunk
    TokenTextSplitter
#Splits text based on:
# tokens
# instead of characters.
)

print("setup completed")
# Out:
# setup completed

# %% [markdown]
# #understanding document structure in Langchain

# %%
#create a simple document
doc=Document(
    page_content="this is the main text content that will be embedded and searched",
    metadata={
        "source":"example.txt",
        "page":1,
        "author":"ashreen kaur",
        "data_created":"2026-05-07",
        "cutom_field":"any_value"
    }
)
# creates one document containing:

# actual text
# metadata information

# %%
print("document structure")
print(f"content:{doc.page_content}")
print(f"content:{doc.metadata}")
type(doc)
# Out:
# document structure
# content:this is the main text content that will be embedded and searched
# content:{'source': 'example.txt', 'page': 1, 'author': 'ashreen kaur', 'data_created': '2026-05-07', 'cutom_field': 'any_value'}
# langchain_core.documents.base.Document

# %%
#why metadata is crucial
# In AI/RAG systems, metadata helps:
# identify source files
# track page numbers
# filter documents
# organize search results
# show citations/references

# %% [markdown]
# Text Files(.txt)

# %%
#create a simple text file
import os
os.makedirs("data/text_files",exist_ok=True)
# Creates a folder named "text_files" inside "data"
# If folder already exists, no error will occur
# The text_files folder is used to store:
# .txt files
# extracted PDF text
# documents for embeddings
# chatbot knowledge base files

# %%
# Creates a Python dictionary named sample_text
# Dictionary stores file path as key and text content as value
sample_text={
    "data/text_files/python_intro.txt":"""1-dataingestion.ipynb
    Python Introduction

Python is a high-level, interpreted programming language known for its simple and readable syntax.

Features of Python:
1. Easy to learn and use
2. Platform independent
3. Supports object-oriented programming
4. Large collection of libraries
5. Widely used in AI, ML, Web Development, and Data Science

Applications of Python:
- Machine Learning
- Data Analysis
- Web Development
- Automation
- Artificial Intelligence

Example Program:
print("Hello World")

Python is one of the most popular programming languages in the world.
    """
}
for filepath,content in sample_text.items():
  with open(filepath,'w',encoding="utf-8") as f:
    f.write(content)
print("sample file created")
# This code loops through each file path and its content stored in the sample_text dictionary using .items(), where filepath represents the file location and content represents the text inside the file.
#The open(filepath, 'w', encoding="utf-8") command opens or creates the file in write mode ('w'), and utf-8 encoding is used to support all types of characters and Unicode text.
#The with statement is used for safe file handling because it automatically closes the file after execution.
#Then f.write(content) writes the given text into the file, and finally print("sample file created") displays a confirmation message after all files are successfully created.
#This approach is commonly used in AI, NLP, and RAG systems for automatically generating and storing text documents or datasets.
# Out:
# sample file created

# %% [markdown]
# TextLoader-Read Single File

# %%
# !pip install langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 80.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 56.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 543.9/543.9 kB 35.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.3.1
#     Uninstalling langchain-core-1.3.1:
#       Successfully uninstalled langchain-core-1.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
from langchain_community.document_loaders import TextLoader

# Creates loader object
loader = TextLoader(
    "data/text_files/python_intro.txt",
    encoding="utf-8"
)

# Loads text file into Document objects
documents = loader.load()

# Shows datatype
print(type(documents))

# Prints full documents
print(documents)

# Shows total documents
print(f"Loaded {len(documents)} document")

# Shows first 100 characters
print(f"Content preview: {documents[0].page_content[:100]}...")

# Shows metadata
print(f"Metadata: {documents[0].metadata}")
# Out:
# <class 'list'>
# [Document(metadata={'source': 'data/text_files/python_intro.txt'}, page_content='1-dataingestion.ipynb\n    Python Introduction\n\nPython is a high-level, interpreted programming language known for its simple and readable syntax.\n\nFeatures of Python:\n1. Easy to learn and use\n2. Platform independent\n3. Supports object-oriented programming\n4. Large collection of libraries\n5. Widely used in AI, ML, Web Development, and Data Science\n\nApplications of Python:\n- Machine Learning\n- Data Analysis\n- Web Development\n- Automation\n- Artificial Intelligence\n\nExample Program:\nprint("Hello World")\n\nPython is one of the most popular programming languages in the world.\n    ')]
# Loaded 1 document
# Content preview: 1-dataingestion.ipynb
#     Python Introduction
#
# Python is a high-level, interpreted programming langu...
# Metadata: {'source': 'data/text_files/python_intro.txt'}

# %% [markdown]
# DirectoryLoader-Multiple Text Files->to read all the text files from the directory loader

# %%
from langchain_community.document_loaders import DirectoryLoader
#load all the text files from the directory
#mports DirectoryLoader from LangChain to load multiple files from a folder.
dir_loaders=DirectoryLoader(#Creates a DirectoryLoader object for loading files from a directory.
    "data/text_files",
    glob="**/*.txt",##pattern to match the files
    loader_cls=TextLoader,##loader class to use(Specifies which loader should be used to read the files.)
    loader_kwargs={'encoding':'utf-8'}, #Extra settings passed to TextLoader.
#utf-8 supports Unicode and special characters.
    show_progress=True #Displays loading progress while files are being processed.
)
documents=dir_loaders.load() #Loads all matching files and converts them into LangChain Document objects.
print(f"Load{len(documents)} documents") #Prints total number of loaded documents.
for i,doc in enumerate(documents):
  print(f"\nDocument{i+1}:")
  print(f"Source:{doc.metadata['source']}")
  print(f"Length:{len(doc.page_content)} characters")
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 1979.38it/s]
# Load1 documents
#
# Document1:
# Source:data/text_files/python_intro.txt
# Length:580 characters

# %% [markdown]
# Text Splitting Strategies

# %%
# #different text splitting strategies
# from langchain.text_splitter import(
#     CharacterTextSplitter, #splits text into chunks based on a fixed number of characters.
#     RecursiveCharacterTextSplitter, #splits text intelligently using separators (like paragraphs → sentences → words) to keep meaning intact.
#     TokenTextSplitter #splits text based on token limits (useful for LLM context windows).
# )
# print(documents)

# %%
# !pip install -U langchain langchain-community langchain-text-splitters
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.8/173.8 kB 13.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langgraph-prebuilt
#     Found existing installation: langgraph-prebuilt 1.0.10
#     Uninstalling langgraph-prebuilt-1.0.10:
#       Successfully uninstalled langgraph-prebuilt-1.0.10
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.1.9
#     Uninstalling langgraph-1.1.9:
#       Successfully uninstalled langgraph-1.1.9
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.2.15
#     Uninstalling langchain-1.2.15:
#       Successfully uninstalled langchain-1.2.15
# ...

# %%
# !pip uninstall -y langchain langchain-community langchain-text-splitters
# !pip install -U langchain langchain-community langchain-text-splitters
# Out:
# Found existing installation: langchain 1.2.18
# Uninstalling langchain-1.2.18:
#   Successfully uninstalled langchain-1.2.18
# Found existing installation: langchain-community 0.4.1
# Uninstalling langchain-community-0.4.1:
#   Successfully uninstalled langchain-community-0.4.1
# Found existing installation: langchain-text-splitters 1.1.2
# Uninstalling langchain-text-splitters-1.1.2:
#   Successfully uninstalled langchain-text-splitters-1.1.2
# ...
#   Using cached langchain-1.2.18-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# ...
# Using cached langchain-1.2.18-py3-none-any.whl (113 kB)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# ...

# %%
# !pip install langchain-text-splitters

# %%
# !pip install langchain langchain-text-splitters

# %%
# !pip install -q langchain langchain-community langchain-text-splitters

# %%
#character text splitter
text=documents[0].page_content
text
#documents is a list of document objects
#[0] accesses the first document in the list
#.page_content extracts the actual text content of that document
#It stores that text into a variable called text
# Out:
# '1-dataingestion.ipynb\n    Python Introduction\n\nPython is a high-level, interpreted programming language known for its simple and readable syntax.\n\nFeatures of Python:\n1. Easy to learn and use\n2. Platform independent\n3. Supports object-oriented programming\n4. Large collection of libraries\n5. Widely used in AI, ML, Web Development, and Data Science\n\nApplications of Python:\n- Machine Learning\n- Data Analysis\n- Web Development\n- Automation\n- Artificial Intelligence\n\nExample Program:\nprint("Hello World")\n\nPython is one of the most popular programming languages in the world.\n    '

# %%
#method 1
#charater-based splitting
print("character text splitter")
char_splitter=CharacterTextSplitter(
    separator="\n", #split on new lines
    chunk_size=200, #max chunk size in characters
    chunk_overlap=20, #overlap between chunks
    length_function=len #how to measure chunk size
)
# Out:
# character text splitter

# %%
print(char_splitter)

# %%
char_chunks=char_splitter.split_text(text)
print(f"Created{len(char_chunks)} chunks") #to see how many chunks are there
print(f"first chunk:{char_chunks[0][:100]}...")
# Out:
# Created3 chunks
# first chunk:1-dataingestion.ipynb
#     Python Introduction
# Python is a high-level, interpreted programming langua...

# %%
print(char_chunks[0])
# Out:
# 1-dataingestion.ipynb
#     Python Introduction
# Python is a high-level, interpreted programming language known for its simple and readable syntax.
# Features of Python:
# 1. Easy to learn and use

# %%
print(char_chunks)
# Out:
# ['1-dataingestion.ipynb\n    Python Introduction\nPython is a high-level, interpreted programming language known for its simple and readable syntax.\nFeatures of Python:\n1. Easy to learn and use', '2. Platform independent\n3. Supports object-oriented programming\n4. Large collection of libraries\n5. Widely used in AI, ML, Web Development, and Data Science\nApplications of Python:\n- Machine Learning', '- Machine Learning\n- Data Analysis\n- Web Development\n- Automation\n- Artificial Intelligence\nExample Program:\nprint("Hello World")\nPython is one of the most popular programming languages in the world.']

# %%
#method-2
#recursive character splitting(recommended)
print("\n recursive character text splitter")
recursive_splitter=RecursiveCharacterTextSplitter(
    separators=["\n\n","\n"," "," "],
    #try these separators in order
    #Split text by paragraph first, then line, then word, then character
    chunk_size=200, #Each chunk can be max 200 characters long
    chunk_overlap=20, #Each chunk shares 20 characters with the next chunk (for context)
    length_function=len #Use Python's built-in len() to measure chunk size
)
recursive_chunks=recursive_splitter.split_text(text)
print(f"created{len(recursive_chunks)} chunks") #Count how many chunks were created
print(f"first chunk:{recursive_chunks[0][:100]}...") #Show first 100 characters of the first chunk
# Out:
#  recursive character text splitter
# created5 chunks
# first chunk:1-dataingestion.ipynb
#     Python Introduction
#
# Python is a high-level, interpreted programming langu...

# %%
print(recursive_chunks[0])
print("-------------------")
print(recursive_chunks[1])
# Out:
# 1-dataingestion.ipynb
#     Python Introduction
#
# Python is a high-level, interpreted programming language known for its simple and readable syntax.
# -------------------
# Features of Python:
# 1. Easy to learn and use
# 2. Platform independent
# 3. Supports object-oriented programming
# 4. Large collection of libraries

# %% [markdown]
# Ingestion and Parsing PDF Documents

# %%
# !pip install pypdf langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.8/338.8 kB 21.4 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("/content/EPICS23_077_23BCE11238-Phase 2_Final Report.pdf")
documents = loader.load()
print(f"Loaded {len(documents)} pages")
# Out:
# Loaded 19 pages

# %% [markdown]
# Load PDF Files

# %%
from langchain_community.document_loaders import(
    PyPDFLoader,
    PyMuPDFLoader,
    UnstructuredPDFLoader
)

# %%
#PypdfLoader
print("PyPdfLoader")
try:
  pypdf_loader=PyPDFLoader("EPICS23_077_23BCE11238-Phase 2_Final Report.pdf")
  pypdf_docs=pypdf_loader.load()
  print(pypdf_docs)
except Exception as e:
  print(f"Error:{e}")
# Out:
# PyPdfLoader
# Error:File path EPICS23_077_23BCE11238-Phase 2_Final Report.pdf is not a valid file or url

# %%
# #method-2
# #PyPDFLoader (fast and accurate)
# print("\n PyMyPDFLoader")
# try:
#   pymupdf_loader=PyMuPDFLoader("")
#   pymupdf_docs=pymupdf_loader.load()
#   print(f"Loaded{len(pymupdf_docs)} pages")
#   print(f"includes detailed metadata")
#   print(pymupdf_docs)
# exception Exception as e:
#   print(f"Error:{e}")

# %%
#method-3
#unstructured pdf loader

# %% [markdown]
# Handling PDF Issues

# %% [markdown]
# Purpose of this section pdfs are notoriously difficult to parse because they:
#
#
#
# *   store text in complex ways(not just simple text)
# *   can have formatting issues
# *   may contain scanned images(requiring OCR)
# *   often have extraction artifacts

# %%
#example of raw pdf extraction
raw_pdf_text="""Artificial intelligence (AI) is intelligence demonstrated by machines.
Machine learning is a subset of AI that enables systems to learn from data.
Deep learning uses neural networks with many layers to analyze data.
Natural language processing allows computers to understand human language.
AI is being used in healthcare, finance, education, and many other fields.
The future of AI holds great promise for solving complex problems."""


#apply the cleaning function
def clean_text(text):
  #remove excessive whitespace
  text=" ".join(text.split())

  #fix ligatures
  text=text.replace("fi","fi")
  text=text.replace("f1","fl")

  return text

cleaned=clean_text(raw_pdf_text)
print("BEFORE:")
print(repr(raw_pdf_text[:100]))
print("\nAFTER:")
print(repr(cleaned[:100]))
# Out:
# BEFORE:
# 'Artificial intelligence (AI) is intelligence demonstrated by machines.\nMachine learning is a subset '
#
# AFTER:
# 'Artificial intelligence (AI) is intelligence demonstrated by machines. Machine learning is a subset '

# %%
# !pip install langchain-text-splitters

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
from typing import List
from langchain_core.documents import Document
class SmartPDFProcessor:
  """Advanced PDF Processing with error handling"""
  def __init__(self,chunk_size=1000,chunk_overlap=100):
    self.chunk_size=chunk_size,
    self.chunk_overlap=chunk_overlap,
    self.text_splitter=RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        separators=[" "]
    )
  def process_pdf(self,pdf_path:str)->List[Document]:
    """process pdf with smart chunking and metadata enhancement"""
    #load pdf
    loader=PyPDFLoader(pdf_path)
    pages=loader.load()

    #process each page
    processed_chunks=[]

    for page_num,page in enumerate(pages):
      #clean text
      cleaned_text=self._clean_text(page.page_content)
      #skip nearly empty pages
      if len(cleaned_text.strip())<50:
        continue
      #create chunks with enhanced metadata
      chunks=self.text_splitter.create_documents(
          texts=[cleaned_text],
          metadatas=[{
              **page.metadata,
              "page":page_num+1,
              "total_pages":len(pages),
              "chunk_method":"smart_pdf_processor",
              "char_count":len(cleaned_text)
          }]
      )
      processed_chunks.extend(chunks)
    return processed_chunks

  def _clean_text(self,text:str)->str:
    """clean extracted text"""
    #remove excessive whitespace
    text=" ".join(text.split())
    #fix common pdf extraction issues
    text=text.replace("fi","fi")
    text=text.replace("f1","fl")

    return text

# %%
# Class Setup __init__

# Sets chunk_size and chunk_overlap as settings
# Creates a RecursiveCharacterTextSplitter to split text into chunks


# process_pdf method

# Loads the PDF using PyPDFLoader
# Loops through each page one by one
# Cleans the page text using _clean_text
# Skips pages with less than 50 characters (empty/useless pages)
# Splits each page into chunks
# Adds extra info (metadata) to each chunk:

# page number
# total pages
# method used
# character count


# Collects all chunks into processed_chunks and returns them


# _clean_text method

# Removes extra spaces/whitespace
# Fixes common PDF extraction errors like:

# "fi" → "fi" (ligature fix)
# "f1" → "fl" (misread character fix)

# %%
preprocessor=SmartPDFProcessor()

# %%
preprocessor

# %%
#process a pdf if available
try:
  smart_chunks=preprocessor.process_pdf("EPICS23_077_23BCE11238-Phase 2_Final Report.pdf")
  print(f"processed into {len(smart_chunks)} smart_chunks")
  #show enhanced metadata
  if smart_chunks:
    print("\nSample chunk metadata:")
    for key,value in smart_chunks[0].metadata.items():
      print(f" {key}:{value}")
except Exception as e:
  print(f"processing error:{e}")
# Out:
# processing error:File path EPICS23_077_23BCE11238-Phase 2_Final Report.pdf is not a valid file or url

# %%
# try block

# Tries to run the code safely without crashing

# preprocessor.process_pdf(...)

# Calls the SmartPDFProcessor to load and chunk the PDF
# Stores all chunks in smart_chunks

# print(f"processed into {len(smart_chunks)} smart_chunks")

# Prints how many chunks were created from the PDF

# if smart_chunks:

# Checks if any chunks were actually created (not empty)

# smart_chunks[0].metadata.items()

# Takes the first chunk and loops through its metadata

# print(f" {key}:{value}")

# Prints each metadata field like:

# page: 1
# total_pages: 10
# char_count: 850



# except Exception as e:

# If anything goes wrong, it catches the error

# print(f"processing error:{e}")

# Prints the error message instead of crashing the notebook

# %% [markdown]
# Word Document Processing

# %%
# !pip install python-docx # installs the package that enables reading/writing .docx Word files in Python
import docx #loads the base docx module giving access to its full namespace
from docx import Document # imports just the Document class, which is the main object used to open, create, and manipulate Word documents
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 15.3 MB/s eta 0:00:00
# ...

# %%
# !pip install docx2txt # installs the docx2txt package that extracts plain text content from .docx files
import docx2txt #loads the library so you can call docx2txt.process() to pull raw text out of Word documents

# %%
from docx import Document as DocxDocument
#imports the Document class from python-docx but renames it to DocxDocument to avoid naming conflicts (e.g., if another library also has a Document class)

# %%
from langchain_community.document_loaders import Docx2txtLoader
from langchain_community.document_loaders import UnstructuredWordDocumentLoader
# Docx2txtLoader — loads a .docx file and extracts its plain text content into LangChain Document objects using the docx2txt library under the hood
# UnstructuredWordDocumentLoader — loads a .docx file with richer parsing via the unstructured library, preserving structural elements like headings, tables, and sections as separate chunks

# %%
#method 1
print("using docx2txtloader")
try:
  docx_loader=Docx2txtLoader("/content/PM_Case_Study.docx")
  # creates a loader object pointing to the uploaded .docx file
  docs=docx_loader.load()
  #reads the file and converts it into a list of LangChain Document objects
  print(f"Loaded {len(docs)} document(s)")
  #prints how many documents were loaded (usually 1 for a single .docx)
  print(f"Content preview: {docs[0].page_content[:200]}...")
  #prints the first 200 characters of the extracted text as a preview
  print(f"Metadata: {docs[0].metadata}")
  #prints metadata like the source file path attached to the document
except Exception as e: #catches any error (file not found, corrupt file, missing package, etc.) and prints it cleanly instead of crashing
  print(f"error:{e}")
# Out:
# using docx2txtloader
# error:File path /content/PM_Case_Study.docx is not a valid file or url

# %%
# !pip install unstructured
# !pip install "unstructured[docx]"  # docx-specific dependencies

#It's a document parsing library that extracts and chunks content from many file formats (PDF, DOCX, HTML, etc.) with structure awareness — headings, tables, lists, etc.
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 26.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 62.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 35.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 33.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.8/167.8 kB 14.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 64.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.7/158.7 kB 10.4 MB/s eta 0:00:00
# ...

# %%
#method 2
print("\n using unstructuredworddocumentloader")
try:
  unstructured_loader=UnstructuredWordDocumentLoader("/content/PM_Case_Study.docx")
except Exception as e:
  print(e)
# Out:
#  using unstructuredworddocumentloader

# %%
#method 2
print("\n using unstructuredworddocumentloader")
try:
  unstructured_loader=UnstructuredWordDocumentLoader("/content/PM_Case_Study.docx")
  unstructured_docs=unstructured_loader.load()
  print(f"loaded {len(unstructured_docs)} elements")
  for i,doc in enumerate(unstructured_docs[:3]):
    print(f"\nElement {i+1}:")
    print(f"Type: {doc.metadata.get('category','unknown')}")
    print(f"content: {doc.page_content[:100]}...")
except Exception as e:
  print(e)
# Out:
#  using unstructuredworddocumentloader
# no such file /content/PM_Case_Study.docx

# %%
# unstructured_docs[0]

# %% [markdown]
# CSV and Excel files-Structured Data

# %%
# !pip install pandas

# %%
import os

# %%
os.makedirs("/content/structured_files",exist_ok=True) #creating a file named structured_data

# %%
# create a sample data
data = {
    'product': ["Laptop", "Smartphone", "Tablet", "Headphones", "Smartwatch"],
    'category': ["Electronics", "Electronics", "Electronics", "Accessories", "Wearables"],
    'price': [999.99, 699.99, 499.99, 199.99, 299.99],
    'stock': [50, 120, 75, 200, 90],
    'description': [
        "High performance laptop with 16GB RAM",
        "Latest smartphone with 5G support",
        "Lightweight tablet with 10-inch display",
        "Noise cancelling wireless headphones",
        "Fitness tracking smartwatch with GPS"
    ]
}
#save as csv
import os
import pandas as pd

# Step 1: Create folder
os.makedirs('/content/structured_data', exist_ok=True)

# Step 2: Create DataFrame
df = pd.DataFrame(data)

# Step 3: Save as CSV
df.to_csv('/content/structured_data/products.csv', index=False)
print("Saved successfully!")
# Out:
# Saved successfully!

# %%
# A Python dictionary data is created with 5 keys — product, category, price, stock, and description — each holding 5 sample product values
# import os and import pandas as pd are imported to handle folder creation and data operations respectively
# os.makedirs('/content/structured_data', exist_ok=True) creates the folder in Colab if it doesn't already exist, without throwing an error if it does
# pd.DataFrame(data) converts the dictionary into a structured table-like DataFrame with 5 rows and 5 columns
# df.to_csv('/content/structured_data/products.csv', index=False) saves the DataFrame as a CSV file named products.csv inside the created folder
# index=False ensures the auto-generated row numbers (0,1,2...) are not saved as an extra column in the CSV
# print("Saved successfully!") confirms the file was created and saved without any errors

# %%
# !pip install openpyxl xlrd xlwt pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 6.7 MB/s eta 0:00:00
# ...

# %%
import openpyxl

# %%
import xlrd

# %%
import xlwt

# %%
import os
import pandas as pd

# Step 1: Create folder
os.makedirs('data/structured_files', exist_ok=True)

# Step 2: Save as excel with multiple sheets
with pd.ExcelWriter('data/structured_files/inventory.xlsx') as writer:
    df.to_excel(writer, sheet_name='Products', index=False)

    # Add another sheet
    summary_data = {
        'category': ['electronics', 'accessories'],
        'total_items': [3, 2],
        'total_value': [1389.97, 109.98]
    }
    pd.DataFrame(summary_data).to_excel(writer, sheet_name='Summary', index=False)

print("Saved successfully!")
# Out:
# Saved successfully!

# %%
# import os — imports the OS module to handle folder/file system operations
# import pandas as pd — imports pandas for creating and saving tabular data
# os.makedirs('data/structured_files', exist_ok=True) — creates the folder data/structured_files/ if it doesn't exist, exist_ok=True prevents error if it already exists
# with pd.ExcelWriter('data/structured_files/inventory.xlsx') as writer — opens an Excel file writer object that can write multiple sheets into one .xlsx file, with block auto-saves and closes the file when done
# df.to_excel(writer, sheet_name='Products', index=False) — writes the existing products DataFrame as the first sheet named Products, index=False skips row numbers
# summary_data = {...} — creates a new dictionary with category-wise summary containing category names, total items count, and total value
# pd.DataFrame(summary_data) — converts the summary dictionary into a DataFrame
# .to_excel(writer, sheet_name='Summary', index=False) — writes the summary DataFrame as a second sheet named Summary in the same Excel file
# print("Saved successfully!") — confirms the Excel file with both sheets was saved without errors
# Sonnet 4.6

# %% [markdown]
# CSV Processing

# %%
from langchain_community.document_loaders import CSVLoader
from langchain_community.document_loaders import UnstructuredCSVLoader

# %%
from langchain_community.document_loaders import CSVLoader

csv_loader = CSVLoader(
    file_path='/content/structured_data/products.csv',  # ✅ correct path
    encoding='utf-8',
    csv_args={
        'delimiter': ',',
        'quotechar': '"'
    }
)

csv_docs = csv_loader.load()
print(f"Loaded {len(csv_docs)} documents (one per row)")
print("\nFirst document:")
print(f"content: {csv_docs[0].page_content}")
print(f"metadata: {csv_docs[0].metadata}")
# Out:
# Loaded 5 documents (one per row)
#
# First document:
# content: product: Laptop
# category: Electronics
# price: 999.99
# stock: 50
# description: High performance laptop with 16GB RAM
# metadata: {'source': '/content/structured_data/products.csv', 'row': 0}

# %%
from typing import List
from langchain_core.documents import Document

#method 2: custom csv processing for better control
print("\n custom csv processing")
def process_csv_intelligently(filepath:str)->List[Document]:
  """process csv withintelligent documnet creation"""
  df=pd.read_csv(filepath)
  documents=[]

  #strategy 1: one document per row with structured content
  for idx,row in df.iterrows():
    #create structured content
    content=f"""product information:
    name:{row['product']}
    category:{row['category']}
    price:${row['price']}
    stock:{row['stock']} units
    description:{row['description']}"""

    #create documnet with rich metadata
    doc=Document(
        page_content=content,
        metadata={
            'source':filepath,
            'row_index':idx,
            'product_name':row['product'],
            'category':row['category'],
            'price':row['price'],
            'data_type':'product_info'
        }
    )
    documents.append(doc)
# Out:
#  custom csv processing

# %%
# from typing import List
# → Imports List for defining list return types.


# from langchain_core.documents import Document
# → Imports LangChain’s Document class.


# #method 2: custom csv processing for better control
# → Comment describing this approach for CSV handling.


# print("\n custom csv processing")
# → Prints “custom csv processing” on a new line.


# def process_csv_intelligently(filepath:str)->List[Document]:
# → Defines a function that takes a file path and returns a list of documents.


# """process csv with intelligent document creation"""
# → Function description explaining its purpose.


# df=pd.read_csv(filepath)
# → Loads the CSV file into a pandas DataFrame.


# documents=[]
# → Creates an empty list to store documents.


# #strategy 1: one document per row with structured content
# → Comment explaining the logic of creating one document per row.


# for idx,row in df.iterrows():
# → Iterates through each row of the DataFrame.


# #create structured content
# → Comment saying formatted text content will be created.


# content=f"""product information:
# → Starts a multi-line formatted string.


# name:{row['product']}
# → Inserts the product name into the content.


# category:{row['category']}
# → Inserts the product category.


# price:${row['price']}
# → Inserts the product price.


# stock:{row['stock']} units
# → Inserts stock quantity with “units”.


# description:{row['descrription']}"""
# → Inserts product description and closes the string.


# #create document with rich metadata
# → Comment explaining that metadata will also be added.


# doc=Document(
# → Creates a new LangChain Document object.


# page_content=content,
# → Stores the formatted text inside the document.


# metadata={
# → Starts metadata dictionary for extra information.


# 'source':filepath,
# → Saves the CSV file path as metadata.


# 'row_index':idx,
# → Saves the current row number.


# 'product_name':row['product'],
# → Saves the product name separately in metadata.


# 'category':row['category'],
# → Saves the category in metadata.


# 'price':row['price'],
# → Saves the price in metadata.


# 'data_type':'product_info'
# → Labels the document type as product information.


# }
# → Ends the metadata dictionary.


# )
# → Ends the Document creation.


# documents.append(doc)
# → Adds the created document to the documents list.

# %%
process_csv_intelligently('/content/structured_data/products.csv')

# %%
# process_csv_intelligently
# → Name of the function being executed.


# ('/content/structured_data/products.csv')
# → Passes the CSV file location as an argument to the function.


# /content/structured_data/products.csv
# → File path of the CSV stored in Google Colab or your system.


# What happens when this line runs:


# The CSV file is opened.


# Data is read into a DataFrame.


# Each row is converted into a LangChain Document.


# Metadata is attached to every document.


# All documents are stored in a list and returned.

# %% [markdown]
# excel processing

# %%
#using pandas for full control
print("pandas-based excel processing")
def process_excel_with_pandas(filepath:str)->List[Document]:
  """process excel with sheet awareness"""
  documents=[]
  #read all sheets
  excel_file=pd.ExcelFile(filepath)
  for sheet_name in excel_file.sheet_names:
    df=pd.read_excel(filepath,sheet_name=sheet_name)
    #craete documnet for each sheet
    sheet_content=f"sheet:{sheet_name}\n"
    sheet_content+=f"columns:{','.join(df.columns)}\n"
    sheet_content+=f"rows:{len(df)}\n\n"
    sheet_content+=df.to_string(index=False)
    doc=Document(
        page_content=sheet_content,
        metadata={
            'source':filepath,
            'sheet_name':sheet_name,
            'num_rows':len(df),
            'num_columns':len(df.columns),
            'data_type':'excel_sheet'
        }
    )
    documents.append(doc)
    return documents
# Out:
# pandas-based excel processing

# %%
# #using pandas for full control
# → Comment explaining that pandas is used for better Excel handling.
# print("pandas-based excel processing")
# → Prints the text “pandas-based excel processing”.
# def process_excel_with_pandas(filepath:str)->List[Document]:
# → Defines a function that takes an Excel file path and returns a list of Document objects.
# """process excel with sheet awareness"""
# → Function description explaining it processes Excel sheets separately.
# documents=[]
# → Creates an empty list to store documents.
# #read all sheets
# → Comment saying all Excel sheets will be read.
# excel_file=pd.ExcelFile(filepath)
# → Opens the Excel file and accesses its sheets.
# for sheet_name in excel_file.sheet_names:
# → Loops through every sheet name in the Excel file.
# df=pd.read_excel(filepath,sheet_name=sheet_name)
# → Reads the current sheet into a pandas DataFrame.
# #create document for each sheet
# → Comment explaining one document will be created per sheet.
# sheet_content=f"sheet:{sheet_name}\n"
# → Starts creating text content with the sheet name.
# sheet_content+=f"columns:{','.join(df.columns)}\n"
# → Adds all column names to the content.
# sheet_content+=f"rows:{len(df)}\n\n"
# → Adds the total number of rows.
# sheet_content+=df.to_string(index=False)
# → Converts the entire DataFrame into text format without row indexes.
# doc=Document(
# → Creates a LangChain Document object.
# page_content=sheet_content,
# → Stores the generated sheet text as document content.
# metadata={
# → Starts metadata information for the document.
# 'source':filepath,
# → Stores the Excel file path.
# 'sheet_name':sheet_name,
# → Stores the current sheet name.
# 'num_rows':len(df),
# → Stores the number of rows in the sheet.
# 'num_columns':len(df.columns),
# → Stores the number of columns in the sheet.
# 'data_type':'excel_sheet'
# → Labels the document type as an Excel sheet.
# }
# → Ends the metadata dictionary.
# )
# → Ends the Document creation.
# documents.append(doc)
# → Adds the created document to the documents list.
# return documents
# → Returns all processed documents.

# Important:

# return documents should be outside the for loop.
# Otherwise, the function stops after processing only the first sheet.

# %%
excel_docs=process_excel_with_pandas('/content/inventory.xlsx')
print(f"processed{len(excel_docs)}sheets")
# Out:
# processed1sheets

# %%
# excel_docs=process_excel_with_pandas('/content/inventory.xlsx')
# → Runs the Excel processing function on inventory.xlsx and stores the result in excel_docs.

# Breakdown:

# excel_docs
# → Variable used to store processed Excel documents.
# =
# → Assigns the returned value from the function.
# process_excel_with_pandas()
# → Calls the function that reads and processes the Excel file.
# '/content/inventory.xlsx'
# → File path of the Excel file in Google Colab.
# print(f"processed{len(excel_docs)}sheets")
# → Prints the number of processed sheets/documents.

# Breakdown:

# print()
# → Displays output on the screen.
# f""
# → Creates a formatted string (f-string).
# len(excel_docs)
# → Counts the total documents inside excel_docs.
# "processed{len(excel_docs)}sheets"
# → Produces output like processed1sheets.

# %%
excel_docs
# Out:
# [Document(metadata={'source': '/content/inventory.xlsx', 'sheet_name': 'Inventory', 'num_rows': 20, 'num_columns': 7, 'data_type': 'excel_sheet'}, page_content='sheet:Inventory\ncolumns:Item ID,Product Name,Category,Stock,Price,Supplier,Last Updated\nrows:20\n\nItem ID Product Name    Category  Stock   Price        Supplier Last Updated\n ITM001       Laptop Electronics    121  320.99     Office Mart   2026-04-17\n ITM002        Chair   Furniture     95  425.67     Office Mart   2026-05-05\n ITM003         Desk   Furniture    102  625.94     ABC Traders   2026-05-07\n ITM004        Chair   Furniture    157 1083.92 Global Supplies   2026-04-29\n ITM005        Mouse Electronics    176  164.14     Prime Store   2026-05-07\n ITM006          Pen  Stationery     32  316.15 Global Supplies   2026-05-10\n ITM007        Chair   Furniture    100 1275.18        TechZone   2026-04-24\n ITM008   Headphones Electronics    196 1335.65     ABC Traders   2026-04-17\n ITM009        Mouse Electronics  
# ...

# %%
#method 2: unstructuredexcelLoader
print("\n unstructuredExcelLoader")
try:
  excel_loader=UnstructuredExcelLoader(
      '/content/structured_data/inventory.xlsx',
      mode="elements"
  )
  unstructured_docs=excel_loader.load()
  print("handles complex excel  features")
  print("preserves formatting info")
  print("requires unstructured library")
except Exception as e:
  print("requires unstructured library with excel support")
# Out:
#  unstructuredExcelLoader
# requires unstructured library with excel support

# %%
# #method 2: unstructuredexcelLoader
# → Comment explaining this is the second method using UnstructuredExcelLoader.


# print("\n unstructuredExcelLoader")
# → Prints “unstructuredExcelLoader” on a new line.


# try:
# → Starts a try block to catch errors safely.


# excel_loader=UnstructuredExcelLoader(
# → Creates an Excel loader object using LangChain’s unstructured loader.


# '/content/structured_data/inventory.xlsx',
# → Gives the path of the Excel file to load.


# mode="elements"
# → Loads the Excel file as separate elements like tables or sections.


# )
# → Ends the loader creation.


# unstructured_docs=excel_loader.load()
# → Loads and converts the Excel file into documents.


# print("handles complex excel  features")
# → Prints that this loader supports advanced Excel features.


# print("preserves formatting info")
# → Prints that formatting information is maintained.


# print("requires unstructured library")
# → Prints that the unstructured library is needed.


# except Exception as e:
# → Catches any error that occurs in the try block.


# print("requires unstructured library with excel support")
# → Prints an error/help message if the required library is missing.

# %% [markdown]
# json parsing and processing

# %%
import json
import os
os.makedirs("data/json_files",exist_ok=True)

# %%
# import json
# → Imports the JSON module to read and write JSON data.


# import os
# → Imports the OS module to work with files and directories.


# os.makedirs("data/json_files", exist_ok=True)
# → Creates the folder data/json_files if it does not already exist.


# Breakdown:


# os.makedirs()
# → Function used to create directories.


# "data/json_files"
# → Folder path to be created.


# exist_ok=True
# → Avoids an error if the folder already exists already.

# %%
#sample nested JSON data
json_data={
    "company":"TechCorp",
    "employees":[
        {
            "id":1,
            "name":"software engineer",
            "role":"jdoefp",
            "skills":["efewlfjlo","fhewfhl"],
            "projects":[
                {"name":"rag system","status":"in progress"},
                {"name":"data pipeline","status":"Completed"}
            ]
        },
        {
            "id":2,
            "name":"fj;oewfj",
            "role":"ehellewl",
            "skills":["elfjew","kd;kqw"],
            "projects":[
                {"hkf":"clwl"},
                {"cslcjw":"k;sdk;"}
            ]
        }
    ],
    "departments":{
        "engineering":{
        "heioewo":65,
        "budget":"lfhle"}

    }
}

# %%
json_data
# Out:
# {'company': 'TechCorp',
#  'employees': [{'id': 1,
#    'name': 'software engineer',
#    'role': 'jdoefp',
#    'skills': ['efewlfjlo', 'fhewfhl'],
#    'projects': [{'name': 'rag system', 'status': 'in progress'},
#     {'name': 'data pipeline', 'status': 'Completed'}]},
#   {'id': 2,
#    'name': 'fj;oewfj',
#    'role': 'ehellewl',
#    'skills': ['elfjew', 'kd;kqw'],
#    'projects': [{'hkf': 'clwl'}, {'cslcjw': 'k;sdk;'}]}],
#  'departments': {'engineering': {'heioewo': 65, 'budget': 'lfhle'}}}

# %%
with open('data/json_files/company_data.json','w') as f:
  json.dump(json_data,f,indent=2)

# %%
# with open('data/json_files/company_data.json','w') as f:
# → Opens the file company_data.json in write mode and stores it in variable f.


# Breakdown:


# with
# → Automatically closes the file after work is done.


# open()
# → Opens or creates a file.


# 'data/json_files/company_data.json'
# → Path and name of the JSON file.


# 'w'
# → Write mode; creates a new file or overwrites existing content.


# as f
# → Stores the opened file object in variable f.





# json.dump(json_data,f,indent=2)
# → Writes Python data from json_data into the JSON file in formatted style.


# Breakdown:


# json.dump()
# → Saves Python data into a JSON file.


# json_data
# → Variable containing the data to save.


# f
# → File object where data will be written.


# indent=2
# → Formats JSON with 2-space indentation for readability.

# %%
#save json lines format
jsonl_data=[
    {"timestamp":"2024-02-02","event":"user_login","user_id":123},
    {"timestamp":"2024-02-02","event":"user_login","user_id":123},
    {"timestamp":"2024-02-02","event":"user_login","user_id":123},
]
with open('data/json_files/events.json','w') as f:
  for item in jsonl_data:
    f.write(json.dumps(item) + '\n')

# %% [markdown]
# json processing strategies

# %%
# !pip install jq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 773.8/773.8 kB 33.0 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import JSONLoader
import json

#method 1: JsonLoader with jq_schema
print("jsonLoader-extract specific fields")

#extract employee information

employee_loader=JSONLoader(
    file_path='data/json_files/company_data.json',
    jq_schema='.employees[]', #jq query to extract each employee
    text_content=False #get full JSON objects
)

employee_docs=employee_loader.load()
print(f"Loaded {len(employee_docs)} employee documents")
print(f"first employee: {employee_docs[0].page_content[:200]}...")
print(employee_docs)
# Out:
# jsonLoader-extract specific fields
# Loaded 2 employee documents
# first employee: {"id": 1, "name": "software engineer", "role": "jdoefp", "skills": ["efewlfjlo", "fhewfhl"], "projects": [{"name": "rag system", "status": "in progress"}, {"name": "data pipeline", "status": "Complete...
# [Document(metadata={'source': '/content/my_project/data/json_files/company_data.json', 'seq_num': 1}, page_content='{"id": 1, "name": "software engineer", "role": "jdoefp", "skills": ["efewlfjlo", "fhewfhl"], "projects": [{"name": "rag system", "status": "in progress"}, {"name": "data pipeline", "status": "Completed"}]}'), Document(metadata={'source': '/content/my_project/data/json_files/company_data.json', 'seq_num': 2}, page_content='{"id": 2, "name": "fj;oewfj", "role": "ehellewl", "skills": ["elfjew", "kd;kqw"], "projects": [{"hkf": "clwl"}, {"cslcjw": "k;sdk;"}]}')]

# %%
#method 2: custom JSON processing for complex structures
from typing import List

print("\n custom JSON Processing")

def process_json_intelligently(filepath:str)->List[Document]:
    """process JSON with intelligent flattening and context preservation"""

    with open(filepath,'r') as f:
        data=json.load(f)

    documents=[]

    #strategy 1: create documents for each employee with full context
    for emp in data.get('employees',[]):

        content=f"""employee profile:
name:{emp['name']}
role:{emp['role']}
skills:{','.join(emp['skills'])}

projects:"""

        for proj in emp.get('projects',[]):
            content += f"\n-{proj['name']} (status:{proj['status']})"

        doc=Document(
            page_content=content,
            metadata={
                'source':filepath,
                'data_type':'employee_profile',
                'employee_id':emp['id'],
                'employee_name':emp['name']
            }
        )

        documents.append(doc)

    return documents
# Out:
#  custom JSON Processing

# %%
# #method 2: custom JSON processing for complex structures
# → Comment explaining this method processes complex JSON data.


# from typing import List
# → Imports List type for type hints.


# print("\n custom JSON Processing")
# → Prints “custom JSON Processing” on a new line.


# def process_json_intelligently(filepath:str)->List[Document]:
# → Defines a function that takes a JSON file path and returns a list of Document objects.


# """process JSON with intelligent flattening and context preservation"""
# → Function description explaining its purpose.


# with open(filepath,'r') as f:
# → Opens the JSON file in read mode.


# data=json.load(f)
# → Loads JSON data from the file into a Python dictionary.


# documents=[]
# → Creates an empty list to store documents.


# #strategy 1: create documents for each employee with full context
# → Comment explaining one document will be created for each employee.


# for emp in data.get('employees',[]):
# → Loops through all employees inside the JSON data.


# content=f"""employee profile:
# → Starts creating formatted employee information text.


# name:{emp['name']}
# → Adds the employee name.


# role:{emp['role']}
# → Adds the employee role/job title.


# skills:{','.join(emp['skills'])}
# → Combines all skills into one comma-separated string.


# projects:"""
# → Adds a projects section heading and ends the multi-line string.


# for proj in emp.get('projects',[]):
# → Loops through all projects of the employee.


# content += f"\n-{proj['name']} (status:{proj['status']})"
# → Adds each project name and its status to the content.


# doc=Document(
# → Creates a LangChain Document object.


# page_content=content,
# → Stores the generated employee profile text.


# metadata={
# → Starts metadata dictionary.


# 'source':filepath,
# → Stores the JSON file path.


# 'data_type':'employee_profile',
# → Labels the document type as employee profile.


# 'employee_id':emp['id'],
# → Stores the employee ID.


# 'employee_name':emp['name']
# → Stores the employee name.


# }
# → Ends the metadata dictionary.


# )
# → Ends the Document creation.


# documents.append(doc)
# → Adds the document to the documents list.


# return documents
# → Returns all created employee documents.

# %%
# process_json_intelligently("data/json_files/company_data.json")

# %% [markdown]
# database parsing

# %%
#create a sample SQLite database
import sqlite3
import os

os.makedirs("data/databases",exist_ok=True)

# %%
#create sample database
conn=sqlite3.connect('data/databases/company.db')
cursor=conn.cursor()

# %%
# #create sample database
# → Comment explaining that a sample database is being created.


# conn=sqlite3.connect('data/databases/company.db')
# → Creates or connects to an SQLite database file named company.db.


# Breakdown:


# sqlite3.connect()
# → Opens a connection to an SQLite database.


# 'data/databases/company.db'
# → Path and name of the database file.


# conn
# → Variable storing the database connection object.





# cursor=conn.cursor()
# → Creates a cursor object to execute SQL queries on the database.


# Breakdown:


# conn.cursor()
# → Creates a cursor from the database connection.


# cursor
# → Variable used to run SQL commands like CREATE, INSERT, SELECT, etc.

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS employees (
    id INTEGER PRIMARY KEY,
    name TEXT,
    role TEXT,
    salary INTEGER
)
""")

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS projects (
    project_id INTEGER PRIMARY KEY,
    employee_id INTEGER,
    project_name TEXT,
    status TEXT
)
""")

# %%
#insert sample data
employees= [
    (1, 'Ashreen', 'Data Scientist', 80000),
    (2, 'Rahul', 'Backend Developer', 70000),
    (3, 'Simran', 'ML Engineer', 90000)
]

projects= [
    (101, 1, 'AI Chatbot', 'Completed'),
    (102, 1, 'Recommendation System', 'In Progress'),
    (103, 2, 'E-commerce Backend', 'Completed'),
    (104, 3, 'Fraud Detection Model', 'In Progress')
]

# %%
cursor.executemany(
    'insert or replace into employees(id,name,role,salary) values(?,?,?,?)',
    employees
)

# %%
# cursor.executemany(
#     'insert or replace into projects(project_id,employee_id,project_name,status) values(?,?,?,?)',
#     projects

# %%
conn.commit()
conn.close
# Out:
# <function Connection.close()>

# %% [markdown]
# Database content extraction

# %%
from langchain_community.utilities import SQLDatabase
from langchain_community.document_loaders import SQLDatabaseLoader

# %%
# #method 1 sqldatabase utility
# db=SQLDatabase.from_uri("sqlite:///data/database/company.db")

# #get database info
# print(f"tables: {db.get_usable_table_names()}")
# print(f"\ntable DDL:")
# print(db.get_table_info())

# %%
# #method 1 sqldatabase utility
# → Comment explaining this is the first method using SQLDatabase utility.


# # db=SQLDatabase.from_uri("sqlite:///data/database/company.db")
# → Creates a connection to the SQLite database file company.db.


# #get database info
# → Comment explaining database information will be retrieved.


# # print(f"tables: {db.get_usable_table_names()}")
# → Prints all usable table names from the database.


# # print(f"\ntable DDL:")
# → Prints the heading “table DDL” on a new line.


# # print(db.get_table_info())
# → Prints the schema/structure information of the database tables.

# %%
# #method 2: custom sql to document conversion

# from typing import List
# from langchain_core.documents import Document
# print("\n custom sql processing")

# def sql_to_documents(db_path:str)->List[Document]:
#   """convert sql database to documents with context"""
#   conn=sqlite3.connect(db_path)
#   cursor=conn.cursor()
#   documents=[]
#   #strategy 1: create documents from each table
#   cursor.execute("select name from sqlite_master where type='table';")
#   tables=cursor.fetchall()

#   for table in tables:
#     table_name=table[0]

#     #get table schema
#     cursor.execute(f"pragma table_info({table_name});")
#     columns=cursor.fetchall()
#     column_names=[col[1] for col in columns]

#     #get table data
#     cursor.execute(f"select * from {table_name}")
#     rows=cursor.fetchall()

#     #create table overview document
#     table_content=f"table:{table_name}\n"
#     table_content+=f"columns:{',' . join(column_names)}\n"
#     table_content+=f"total records: {len(rows)}\n\n"

#     #add sample records
#     table_content+="Sample records:\n"
#     for row in rows[:5]:
#       record=dict(zip(column_names,row))
#       table_content+=f"{record}\n"
#     doc=Document(
#         page_content=table_content,
#         metadata={
#             'source':db_path,
#             'table_name':table_name,
#             'num_records':len(rows),
#             'data_type':'sql_table'
#         }
#     )
#     documents.append(doc)
# return documents

# %%
# #method 2: custom sql to document conversion
# → Comment explaining this method converts SQL data into documents.


# # from typing import List
# → Imports List type for type hints.


# # from langchain_core.documents import Document
# → Imports LangChain’s Document class.


# # print("\n custom sql processing")
# → Prints “custom sql processing” on a new line.


# # def sql_to_documents(db_path:str)->List[Document]:
# → Defines a function that converts SQL database data into documents.


# # """convert sql database to documents with context"""
# → Function description explaining its purpose.


# # conn=sqlite3.connect(db_path)
# → Connects to the SQLite database file.


# # cursor=conn.cursor()
# → Creates a cursor object to execute SQL queries.


# # documents=[]
# → Creates an empty list to store documents.


# # #strategy 1: create documents from each table
# → Comment explaining one document will be created per table.


# # cursor.execute("select name from sqlite_master where type='table';")
# → Retrieves all table names from the SQLite database.


# # tables=cursor.fetchall()
# → Stores all table names in the tables variable.


# # for table in tables:
# → Loops through every table in the database.


# # table_name=table[0]
# → Extracts the table name from the tuple.


# # #get table schema
# → Comment explaining schema information will be fetched.


# # cursor.execute(f"pragma table_info({table_name});")
# → Retrieves column information of the current table.


# # columns=cursor.fetchall()
# → Stores all column details.


# # column_names=[col[1] for col in columns]
# → Extracts only the column names using list comprehension.


# # #get table data
# → Comment explaining table records will be fetched.


# # cursor.execute(f"select * from {table_name}")
# → Retrieves all rows from the current table.


# # rows=cursor.fetchall()
# → Stores all table records.


# # #create table overview document
# → Comment explaining document content will be created.


# # table_content=f"table:{table_name}\n"
# → Starts document content with the table name.


# # table_content+=f"columns:{',' . join(column_names)}\n"
# → Adds all column names as comma-separated text.


# # table_content+=f"total records: {len(rows)}\n\n"
# → Adds the total number of records in the table.


# # #add sample records
# → Comment explaining sample rows will be included.


# # table_content+="Sample records:\n"
# → Adds a heading for sample records.


# # for row in rows[:5]:
# → Loops through the first 5 rows only.


# # record=dict(zip(column_names,row))
# → Combines column names and row values into a dictionary.


# # table_content+=f"{record}\n"
# → Adds the record dictionary to the document content.


# # doc=Document(
# → Creates a LangChain Document object.


# # page_content=table_content,
# → Stores the generated table text as document content.


# # metadata={
# → Starts metadata dictionary.


# # 'source':db_path,
# → Stores the database path.


# # 'table_name':table_name,
# → Stores the current table name.


# # 'num_records':len(rows),
# → Stores the total number of records.


# # 'data_type':'sql_table'
# → Labels the document type as SQL table data.


# # }
# → Ends the metadata dictionary.


# # )
# → Ends the Document creation.


# # documents.append(doc)
# → Adds the document to the documents list.


# # return documents
# → Returns all created documents.
